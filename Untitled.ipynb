# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly as ptp
import seaborn as sns
import scipy as scy
import os

# %%
pwd()
# Out:
# 'C:\\Users\\DELL\\Udemy classes\\Python For ML\\pandas practice notes'

# %%
ls
# Out:
#  Volume in drive C is SSD
#  Volume Serial Number is 6A05-E850
#
#  Directory of C:\Users\DELL\Udemy classes\Python For ML\pandas practice notes
#
# 15-03-2023  20:36    <DIR>          .
# 15-03-2023  20:36    <DIR>          ..
# 11-03-2023  10:03    <DIR>          .ipynb_checkpoints
# 01-01-2023  21:59            68,864 Combining of Data Frames.ipynb
# 27-01-2023  17:20             5,513 Excample.xlsx
# 21-12-2022  22:10            93,520 Groupby Operations.ipynb
# 27-01-2023  17:38           140,230 INPUT_&_OUT PUTS IN PANDAS.READ.ipynb
# 20-12-2022  20:47            99,611 Missing Data.ipynb
# 27-01-2023  17:20                51 new_file.csv
# 03-02-2023  17:34         1,107,754 Pandas Class Practice.ipynb
# 19-12-2022  21:11           274,345 Pandas Conditions,Methods Practice 01.ipynb
# 09-03-2023  14:35            31,491 senate_national_forecast.csv
# 03-01-2023  21:15            39,660 text Methods and Strings.ipynb
# ...

# %%
df=pd.read_csv('senate_national_forecast.csv')
df.head(10)
# Out:
#   forecastdate state party    model  win_probability  mean_seats  \
# 0   2018-08-24    US     D  classic           0.2846       48.97
# 1   2018-08-24    US     R  classic           0.7154       51.03
# 2   2018-08-25    US     D  classic           0.3013       49.07
# 3   2018-08-25    US     R  classic           0.6987       50.93
# 4   2018-08-26    US     D  classic           0.2964       49.04
# 5   2018-08-26    US     R  classic           0.7036       50.96
# 6   2018-08-27    US     D  classic           0.2904       49.02
# 7   2018-08-27    US     R  classic           0.7096       50.98
# 8   2018-08-28    US     D  classic           0.3126       49.14
# 9   2018-08-28    US     R  classic           0.6874       50.86
#
#    median_seats  p10_seats  p90_seats  margin  p10_margin  p90_margin
# 0          49.0       46.0       52.0   21.75       17.13       26.37
# 1          51.0       48.0       54.0  -21.75      -17.13      -26.37
# ...

# %%
len(df)
# Out:
# 450

# %%
df_gain=df[df['p10_margin']>0]
df_loss=df[df['p10_margin']<0]

# %%
df_gain
# Out:
#     forecastdate state party    model  win_probability  mean_seats  \
# 0     2018-08-24    US     D  classic           0.2846       48.97
# 2     2018-08-25    US     D  classic           0.3013       49.07
# 4     2018-08-26    US     D  classic           0.2964       49.04
# 6     2018-08-27    US     D  classic           0.2904       49.02
# 8     2018-08-28    US     D  classic           0.3126       49.14
# ..           ...   ...   ...      ...              ...         ...
# 440   2018-11-02    US     D     lite           0.1610       48.01
# 442   2018-11-03    US     D     lite           0.1681       48.08
# 444   2018-11-04    US     D     lite           0.1611       48.03
# 446   2018-11-05    US     D     lite           0.2089       48.31
# 448   2018-11-06    US     D     lite           0.2097       48.31
#
#      median_seats  p10_seats  p90_seats  margin  p10_margin  p90_margin
# 0            49.0       46.0       52.0   21.75       17.13       26.37
# ...

# %%
df_gain[df_gain['win_probability']>df_gain['win_probability'].mean()]
# Out:
#     forecastdate state party    model  win_probability  mean_seats  \
# 0     2018-08-24    US     D  classic           0.2846       48.97
# 2     2018-08-25    US     D  classic           0.3013       49.07
# 4     2018-08-26    US     D  classic           0.2964       49.04
# 6     2018-08-27    US     D  classic           0.2904       49.02
# 8     2018-08-28    US     D  classic           0.3126       49.14
# ..           ...   ...   ...      ...              ...         ...
# 370   2018-09-28    US     D     lite           0.3058       48.84
# 372   2018-09-29    US     D     lite           0.3012       48.83
# 374   2018-09-30    US     D     lite           0.3026       48.83
# 376   2018-10-01    US     D     lite           0.2601       48.53
# 378   2018-10-02    US     D     lite           0.2740       48.61
#
#      median_seats  p10_seats  p90_seats  margin  p10_margin  p90_margin
# 0            49.0       46.0       52.0   21.75       17.13       26.37
# ...

# %%
df['margin'].max()
# Out:
# 22.41

# %%
df_gain['margin'].value_counts()
# Out:
# 22.06    5
# 20.65    4
# 20.70    4
# 22.23    4
# 21.93    4
#         ..
# 21.57    1
# 21.83    1
# 22.20    1
# 22.17    1
# 21.75    1
# Name: margin, Length: 147, dtype: int64

# %%
df_loss
# Out:
#     forecastdate state party    model  win_probability  mean_seats  \
# 1     2018-08-24    US     R  classic           0.7154       51.03
# 3     2018-08-25    US     R  classic           0.6987       50.93
# 5     2018-08-26    US     R  classic           0.7036       50.96
# 7     2018-08-27    US     R  classic           0.7096       50.98
# 9     2018-08-28    US     R  classic           0.6874       50.86
# ..           ...   ...   ...      ...              ...         ...
# 441   2018-11-02    US     R     lite           0.8390       51.99
# 443   2018-11-03    US     R     lite           0.8319       51.92
# 445   2018-11-04    US     R     lite           0.8389       51.97
# 447   2018-11-05    US     R     lite           0.7911       51.69
# 449   2018-11-06    US     R     lite           0.7903       51.69
#
#      median_seats  p10_seats  p90_seats  margin  p10_margin  p90_margin
# 1            51.0       48.0       54.0  -21.75      -17.13      -26.37
# ...

# %%
df_gain.hist()
# Out:
# array([[<AxesSubplot:title={'center':'win_probability'}>,
#         <AxesSubplot:title={'center':'mean_seats'}>,
#         <AxesSubplot:title={'center':'median_seats'}>],
#        [<AxesSubplot:title={'center':'p10_seats'}>,
#         <AxesSubplot:title={'center':'p90_seats'}>,
#         <AxesSubplot:title={'center':'margin'}>],
#        [<AxesSubplot:title={'center':'p10_margin'}>,
#         <AxesSubplot:title={'center':'p90_margin'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
sns.pairplot(df)

# %%
sns.pairplot(df_gain)

# %%
sns.barplot(data=df_loss,x='mean_seats',y='median_seats')
# Out:
# <AxesSubplot:xlabel='mean_seats', ylabel='median_seats'>

# %%
df_loss.head()
# Out:
#   forecastdate state party    model  win_probability  mean_seats  \
# 1   2018-08-24    US     R  classic           0.7154       51.03
# 3   2018-08-25    US     R  classic           0.6987       50.93
# 5   2018-08-26    US     R  classic           0.7036       50.96
# 7   2018-08-27    US     R  classic           0.7096       50.98
# 9   2018-08-28    US     R  classic           0.6874       50.86
#
#    median_seats  p10_seats  p90_seats  margin  p10_margin  p90_margin
# 1          51.0       48.0       54.0  -21.75      -17.13      -26.37
# 3          51.0       48.0       54.0  -21.84      -17.24      -26.49
# 5          51.0       48.0       54.0  -21.82      -17.23      -26.40
# 7          51.0       48.0       54.0  -21.69      -17.12      -26.26
# 9          51.0       48.0       54.0  -21.87      -17.32      -26.48

# %%
df.truncate()
# Out:
#     forecastdate state party    model  win_probability  mean_seats  \
# 0     2018-08-24    US     D  classic           0.2846       48.97
# 1     2018-08-24    US     R  classic           0.7154       51.03
# 2     2018-08-25    US     D  classic           0.3013       49.07
# 3     2018-08-25    US     R  classic           0.6987       50.93
# 4     2018-08-26    US     D  classic           0.2964       49.04
# ..           ...   ...   ...      ...              ...         ...
# 445   2018-11-04    US     R     lite           0.8389       51.97
# 446   2018-11-05    US     D     lite           0.2089       48.31
# 447   2018-11-05    US     R     lite           0.7911       51.69
# 448   2018-11-06    US     D     lite           0.2097       48.31
# 449   2018-11-06    US     R     lite           0.7903       51.69
#
#      median_seats  p10_seats  p90_seats  margin  p10_margin  p90_margin
# 0            49.0       46.0       52.0   21.75       17.13       26.37
# ...

# %%
df.columns
# Out:
# Index(['forecastdate', 'state', 'party', 'model', 'win_probability',
#        'mean_seats', 'median_seats', 'p10_seats', 'p90_seats', 'margin',
#        'p10_margin', 'p90_margin'],
#       dtype='object')

# %%
df[['model', 'win_probability','mean_seats', 'median_seats', 'p10_seats', 'p90_seats', 'margin','p10_margin', 'p90_margin']]
# Out:
#        model  win_probability  mean_seats  median_seats  p10_seats  p90_seats  \
# 0    classic           0.2846       48.97          49.0       46.0       52.0
# 1    classic           0.7154       51.03          51.0       48.0       54.0
# 2    classic           0.3013       49.07          49.0       46.0       52.0
# 3    classic           0.6987       50.93          51.0       48.0       54.0
# 4    classic           0.2964       49.04          49.0       46.0       52.0
# ..       ...              ...         ...           ...        ...        ...
# 445     lite           0.8389       51.97          52.0       49.0       55.0
# 446     lite           0.2089       48.31          49.0       45.0       51.0
# 447     lite           0.7911       51.69          51.0       49.0       55.0
# 448     lite           0.2097       48.31          49.0       45.0       51.0
# 449     lite           0.7903       51.69          51.0       49.0       55.0
#
# ...

# %%
df_gain[['model', 'win_probability','mean_seats']]
# Out:
#        model  win_probability  mean_seats
# 0    classic           0.2846       48.97
# 2    classic           0.3013       49.07
# 4    classic           0.2964       49.04
# 6    classic           0.2904       49.02
# 8    classic           0.3126       49.14
# ..       ...              ...         ...
# 440     lite           0.1610       48.01
# 442     lite           0.1681       48.08
# 444     lite           0.1611       48.03
# 446     lite           0.2089       48.31
# 448     lite           0.2097       48.31
#
# [225 rows x 3 columns]

# %%
df.value_counts()
# Out:
# forecastdate  state  party  model    win_probability  mean_seats  median_seats  p10_seats  p90_seats  margin  p10_margin  p90_margin
# 2018-08-24    US     D      classic  0.2846           48.97       49.0          46.0       52.0        21.75   17.13       26.37        1
# 2018-10-19    US     D      deluxe   0.2004           48.51       49.0          45.0       51.0        21.11   17.16       25.12        1
# 2018-10-14    US     D      deluxe   0.2019           48.49       49.0          45.0       51.0        21.66   17.55       25.69        1
#                             classic  0.2010           48.53       49.0          46.0       51.0        21.46   17.33       25.51        1
# 2018-10-13    US     R      lite     0.8189           51.88       52.0          49.0       55.0       -20.35  -15.93      -24.75        1
#                                                                                                                                        ..
# ...

# %%
df_indx=df.set_index('model')

# %%
df_indx.groupby(by=['model'])

# %%
plt.bar(df['margin'],df['win_probability'])
# Out:
# <BarContainer object of 450 artists>

# %%
plt.pie(df['win_probability'])
plt.plot()
# Out:
# []

# %%
df.head(5)
# Out:
#   forecastdate state party    model  win_probability  mean_seats  \
# 0   2018-08-24    US     D  classic           0.2846       48.97
# 1   2018-08-24    US     R  classic           0.7154       51.03
# 2   2018-08-25    US     D  classic           0.3013       49.07
# 3   2018-08-25    US     R  classic           0.6987       50.93
# 4   2018-08-26    US     D  classic           0.2964       49.04
#
#    median_seats  p10_seats  p90_seats  margin  p10_margin  p90_margin
# 0          49.0       46.0       52.0   21.75       17.13       26.37
# 1          51.0       48.0       54.0  -21.75      -17.13      -26.37
# 2          49.0       46.0       52.0   21.84       17.24       26.49
# 3          51.0       48.0       54.0  -21.84      -17.24      -26.49
# 4          49.0       46.0       52.0   21.82       17.23       26.40

# %%
df['total_margin']=df['margin']+df['p10_margin']+df['p90_margin']

# %%
df
# Out:
#     forecastdate state party    model  win_probability  mean_seats  \
# 0     2018-08-24    US     D  classic           0.2846       48.97
# 1     2018-08-24    US     R  classic           0.7154       51.03
# 2     2018-08-25    US     D  classic           0.3013       49.07
# 3     2018-08-25    US     R  classic           0.6987       50.93
# 4     2018-08-26    US     D  classic           0.2964       49.04
# ..           ...   ...   ...      ...              ...         ...
# 445   2018-11-04    US     R     lite           0.8389       51.97
# 446   2018-11-05    US     D     lite           0.2089       48.31
# 447   2018-11-05    US     R     lite           0.7911       51.69
# 448   2018-11-06    US     D     lite           0.2097       48.31
# 449   2018-11-06    US     R     lite           0.7903       51.69
#
#      median_seats  p10_seats  p90_seats  margin  p10_margin  p90_margin  \
# 0            49.0       46.0       52.0   21.75       17.13       26.37
# ...

# %%
df=df[df['total_margin']>0]

# %%
df.head()
# Out:
#   forecastdate state party    model  win_probability  mean_seats  \
# 0   2018-08-24    US     D  classic           0.2846       48.97
# 2   2018-08-25    US     D  classic           0.3013       49.07
# 4   2018-08-26    US     D  classic           0.2964       49.04
# 6   2018-08-27    US     D  classic           0.2904       49.02
# 8   2018-08-28    US     D  classic           0.3126       49.14
#
#    median_seats  p10_seats  p90_seats  margin  p10_margin  p90_margin  \
# 0          49.0       46.0       52.0   21.75       17.13       26.37
# 2          49.0       46.0       52.0   21.84       17.24       26.49
# 4          49.0       46.0       52.0   21.82       17.23       26.40
# 6          49.0       46.0       52.0   21.69       17.12       26.26
# 8          49.0       46.0       52.0   21.87       17.32       26.48
#
#    total_margin
# 0         65.25
# 2         65.57
# 4         65.45
# 6         65.07
# 8         65.67

# %%
x=df['total_margin']
y=df['margin']

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,color='red')
sns.scatterplot(data=df,x=x,y=y)
# Out:
# <AxesSubplot:xlabel='total_margin', ylabel='margin'>

# %%
np.polyfit(x,y,deg=1)
# Out:
# array([ 0.33422948, -0.05538508])

# %%
df.head()
# Out:
#   forecastdate state party    model  win_probability  mean_seats  \
# 0   2018-08-24    US     D  classic           0.2846       48.97
# 2   2018-08-25    US     D  classic           0.3013       49.07
# 4   2018-08-26    US     D  classic           0.2964       49.04
# 6   2018-08-27    US     D  classic           0.2904       49.02
# 8   2018-08-28    US     D  classic           0.3126       49.14
#
#    median_seats  p10_seats  p90_seats  margin  p10_margin  p90_margin  \
# 0          49.0       46.0       52.0   21.75       17.13       26.37
# 2          49.0       46.0       52.0   21.84       17.24       26.49
# 4          49.0       46.0       52.0   21.82       17.23       26.40
# 6          49.0       46.0       52.0   21.69       17.12       26.26
# 8          49.0       46.0       52.0   21.87       17.32       26.48
#
#    total_margin
# 0         65.25
# 2         65.57
# 4         65.45
# 6         65.07
# 8         65.67

# %%
x=df['p90_seats']
y=df['p10_seats']

# %%
sns.regplot(data=df,x=x,y=y)
# Out:
# <AxesSubplot:xlabel='p90_seats', ylabel='p10_seats'>

# %%
np.polyfit(x,y,deg=1)
# Out:
# array([ 0.51722689, 18.66848739])

# %%
x_spaces=np.linspace(50,60,100)

# %%
y1=0.94160277*x_spaces+(-3.15088292)

# %%
sns.scatterplot(data=df,x=df['p90_seats'],y=df['p10_seats'])
plt.plot(x_spaces,y1,color='red')

# %%
sns.scatterplot(data=df,x=df['p90_seats'],y=df['p10_seats'])
# Out:
# <AxesSubplot:xlabel='p90_seats', ylabel='p10_seats'>
