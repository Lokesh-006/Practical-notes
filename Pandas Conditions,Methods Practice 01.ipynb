# %% [markdown]
# # Conditional Filtering

# %%
import pandas as pd
import numpy as np

# %%
tips_csv = 'C:\\Users\\DELL\\Udemy classes\\UNZIP_FOR_NOTEBOOKS_FINAL\\03-Pandas\\tips.csv'
df = pd.read_csv(tips_csv)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# ## Conditions

# %%
# the df['total_bill'] Column values less than 30 is condition

# %%
bool_series = df['total_bill'] < 30

# %%
bool_series # yes we got bool values after condtion execution
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 239    True
# 240    True
# 241    True
# 242    True
# 243    True
# Name: total_bill, Length: 244, dtype: bool

# %%
# Let us check the data frame
# show only the data which is only in give condition
df[bool_series]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [212 rows x 11 columns]

# %%
# Another methode 
# now  check greater than 30
df[df['total_bill']>30]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 11        35.26   5.00  Female     No   Sun  Dinner     4              8.82
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 39        31.27   5.00    Male     No   Sat  Dinner     3             10.42
# 44        30.40   5.60    Male     No   Sun  Dinner     4              7.60
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 52        34.81   5.20  Female     No   Sun  Dinner     4              8.70
# 56        38.01   3.00    Male    Yes   Sat  Dinner     4              9.50
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 83        32.68   5.00    Male    Yes  Thur   Lunch     2             16.34
# 85        34.83   5.17  Female     No  Thur   Lunch     4              8.71
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 112       38.07   4.00    Male     No   Sun  Dinner     3             12.69
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 142       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 167       31.71   4.50    Male     No   Sun  Dinner     4              7.93
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 173       31.85   3.18    Male    Yes   Sun  Dinner     2             15.92
# 175       32.90   3.11    Male    Yes   Sun  Dinner     2             16.45
# 179       34.63   3.55    Male    Yes   Sun  Dinner     2             17.32
# 180       34.65   3.68    Male    Yes   Sun  Dinner     4              8.66
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 187       30.46   2.00    Male    Yes   Sun  Dinner     5              6.09
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 207       38.73   3.00    Male    Yes   Sat  Dinner     4              9.68
# 210       30.06   2.00    Male    Yes   Sat  Dinner     3             10.02
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 219       30.14   3.09  Female    Yes   Sat  Dinner     4              7.54
# 237       32.83   1.17    Male    Yes   Sat  Dinner     2             16.42
# 238       35.83   4.67  Female     No   Sat  Dinner     3             11.94
#
#                 Payer Name         CC Number Payment ID
# 11            Diane Macias  4577817359320969    Sun6686
# 23          Lance Peterson  3542584061609808     Sat239
# 39       Mr. Brandon Berry  6011525851069856    Sat6373
# 44             Todd Cooper      503846761263    Sun2274
# 47            James Barnes  3552002592874186    Sun9677
# 52            Emily Daniel  4291280793094374    Sun6165
# 56   James Christensen DDS   349793629453226    Sat8903
# 59             Brian Ortiz  6596453823950595    Sat8139
# 83           Daniel Murphy  5356177501009133   Thur8801
# 85             Shawna Cook  6011787464177340   Thur7972
# 95           Aaron Bentley   180026611638690    Fri9628
# 102          Heather Cohen   379771118886604    Sat6240
# 112             Jeff Lopez  3572865915176463     Sun591
# 141         Steven Carlson  3526515703718508   Thur1025
# 142           Eric Andrews  4356531761046453   Thur3621
# 156          Ryan Gonzales  3523151482063321    Sun7518
# 167         Michael Lawson  3566285921227119    Sun3719
# 170          Gregory Clark  5473850968388236    Sat1954
# 173            Scott Perez  3577115550328507    Sun9335
# 175        Nathan Reynolds   370307040837149    Sun5109
# 179           Brian Bailey   346656312114848    Sun9851
# 180       James Hebert DDS      676168737648    Sun7544
# 182           Jose Parsons  4112207559459910    Sun2337
# 184            Stephen Cox  3547798222044029    Sun5140
# 187          David Barrett  4792882899700988    Sun9987
# 197            Brooke Soto  5544902205760175   Thur9313
# 207          Ricky Ramirez   347817964484033    Sat4505
# 210          Shawn Mendoza    30184049218122    Sat8361
# 212        Alex Williamson      676218815212    Sat4590
# 219           Shelby House      502097403252    Sat8863
# 237           Thomas Brown  4284722681265508    Sat2929
# 238         Kimberly Crane      676184013727    Sat9777

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df[df['size'] >= 4]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# 5         25.29  4.71    Male     No   Sun  Dinner     4              6.32
# 7         26.88  3.12    Male     No   Sun  Dinner     4              6.72
# 11        35.26  5.00  Female     No   Sun  Dinner     4              8.82
# 13        18.43  3.00    Male     No   Sun  Dinner     4              4.61
# 23        39.42  7.58    Male     No   Sat  Dinner     4              9.86
# 25        17.81  2.34    Male     No   Sat  Dinner     4              4.45
# 31        18.35  2.50    Male     No   Sat  Dinner     4              4.59
# 33        20.69  2.45  Female     No   Sat  Dinner     4              5.17
# 44        30.40  5.60    Male     No   Sun  Dinner     4              7.60
# 47        32.40  6.00    Male     No   Sun  Dinner     4              8.10
# 52        34.81  5.20  Female     No   Sun  Dinner     4              8.70
# 54        25.56  4.34    Male     No   Sun  Dinner     4              6.39
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4              9.50
# 59        48.27  6.73    Male     No   Sat  Dinner     4             12.07
# 63        18.29  3.76    Male    Yes   Sat  Dinner     4              4.57
# 77        27.20  4.00    Male     No  Thur   Lunch     4              6.80
# 85        34.83  5.17  Female     No  Thur   Lunch     4              8.71
# 95        40.17  4.73    Male    Yes   Fri  Dinner     4             10.04
# 116       29.93  5.07    Male     No   Sun  Dinner     4              7.48
# 119       24.08  2.92  Female     No  Thur   Lunch     4              6.02
# 125       29.80  4.20  Female     No  Thur   Lunch     6              4.97
# 141       34.30  6.70    Male     No  Thur   Lunch     6              5.72
# 142       41.19  5.00    Male     No  Thur   Lunch     5              8.24
# 143       27.05  5.00  Female     No  Thur   Lunch     6              4.51
# 153       24.55  2.00    Male     No   Sun  Dinner     4              6.14
# 154       19.77  2.00    Male     No   Sun  Dinner     4              4.94
# 155       29.85  5.14  Female     No   Sun  Dinner     5              5.97
# 156       48.17  5.00    Male     No   Sun  Dinner     6              8.03
# 157       25.00  3.75  Female     No   Sun  Dinner     4              6.25
# 159       16.49  2.00    Male     No   Sun  Dinner     4              4.12
# 160       21.50  3.50    Male     No   Sun  Dinner     4              5.38
# 167       31.71  4.50    Male     No   Sun  Dinner     4              7.93
# 180       34.65  3.68    Male    Yes   Sun  Dinner     4              8.66
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4              5.79
# 185       20.69  5.00    Male     No   Sun  Dinner     5              4.14
# 187       30.46  2.00    Male    Yes   Sun  Dinner     5              6.09
# 197       43.11  5.00  Female    Yes  Thur   Lunch     4             10.78
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4              5.13
# 207       38.73  3.00    Male    Yes   Sat  Dinner     4              9.68
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4              6.47
# 212       48.33  9.00    Male     No   Sat  Dinner     4             12.08
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5              5.63
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4              7.54
# 227       20.45  3.00    Male     No   Sat  Dinner     4              5.11
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4              6.00
#
#                 Payer Name         CC Number Payment ID
# 4             Tonya Carter  4832732618637221    Sun2251
# 5               Erik Smith   213140353657882    Sun9679
# 7              Robert Buck  3514785077705092    Sun8157
# 11            Diane Macias  4577817359320969    Sun6686
# 13            Joshua Jones  6011163105616890    Sun2971
# 23          Lance Peterson  3542584061609808     Sat239
# 25          Robert Perkins    30502930499388     Sat907
# 31          Danny Santiago      630415546013    Sat4947
# 33           Amber Francis   377742985258914    Sat6649
# 44             Todd Cooper      503846761263    Sun2274
# 47            James Barnes  3552002592874186    Sun9677
# 52            Emily Daniel  4291280793094374    Sun6165
# 54            Ronald Owens  6569607991983380    Sun9470
# 56   James Christensen DDS   349793629453226    Sat8903
# 59             Brian Ortiz  6596453823950595    Sat8139
# 63               Chad Hart      580171498976    Sat4178
# 77              John Davis    30344778738589   Thur4924
# 85             Shawna Cook  6011787464177340   Thur7972
# 95           Aaron Bentley   180026611638690    Fri9628
# 116            Shawn Blake  4689079711213722      Sun22
# 119         Melanie Jordan      676212062720   Thur8063
# 125         Angela Sanchez      503857080488   Thur3948
# 141         Steven Carlson  3526515703718508   Thur1025
# 142           Eric Andrews  4356531761046453   Thur3621
# 143           Regina Jones     4311048695487   Thur6179
# 153         Todd Patterson  4416804908942159    Sun8670
# 154            James Smith   213169731428229    Sun5814
# 155         Madison Wilson  4210875236164664    Sun9176
# 156          Ryan Gonzales  3523151482063321    Sun7518
# 157           Laura Robles   213158685144262    Sun7015
# 159       Christopher Soto    30501814271434    Sun1781
# 160        Travis Gonzalez  3527668419764685     Sun245
# 167         Michael Lawson  3566285921227119    Sun3719
# 180       James Hebert DDS      676168737648    Sun7544
# 183      Dr. Michael James     4718501859162    Sun6059
# 185          Joseph Howell    30362407455623    Sun5842
# 187          David Barrett  4792882899700988    Sun9987
# 197            Brooke Soto  5544902205760175   Thur9313
# 204              Scott Kim  3570611756827620   Thur2160
# 207          Ricky Ramirez   347817964484033    Sat4505
# 211         Christopher Li  6011962464150569    Sat6735
# 212        Alex Williamson      676218815212    Sat4590
# 216      Shawn Barnett PhD     4590982568244    Sat7320
# 219           Shelby House      502097403252    Sat8863
# 227         Robert Bradley   213141668145910    Sat4319
# 230        Michael Osborne     4258682154026    Sat7872

# %%
df[df['sex'] == 'Female']
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# 11        35.26  5.00  Female     No   Sun  Dinner     4              8.82
# 14        14.83  3.02  Female     No   Sun  Dinner     2              7.42
# 16        10.33  1.67  Female     No   Sun  Dinner     3              3.44
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2              5.04
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2             11.06
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 4          Tonya Carter  4832732618637221    Sun2251
# 11         Diane Macias  4577817359320969    Sun6686
# 14        Vanessa Jones    30016702287574    Sun3848
# 16     Elizabeth Foster  4240025044626033    Sun9715
# ..                  ...               ...        ...
# 226          Ruth Weiss  5268689490381635    Fri6359
# 229    Jennifer Russell     4793003293608    Sat3943
# 238      Kimberly Crane      676184013727    Sat9777
# 240      Monica Sanders  3506806155565404    Sat1766
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [87 rows x 11 columns]

# %%
df[df['time']  == 'Lunch']
# Out:
#      total_bill   tip     sex smoker   day   time  size  price_per_person  \
# 77        27.20  4.00    Male     No  Thur  Lunch     4              6.80
# 78        22.76  3.00    Male     No  Thur  Lunch     2             11.38
# 79        17.29  2.71    Male     No  Thur  Lunch     2              8.64
# 80        19.44  3.00    Male    Yes  Thur  Lunch     2              9.72
# 81        16.66  3.40    Male     No  Thur  Lunch     2              8.33
# ..          ...   ...     ...    ...   ...    ...   ...               ...
# 222        8.58  1.92    Male    Yes   Fri  Lunch     1              8.58
# 223       15.98  3.00  Female     No   Fri  Lunch     3              5.33
# 224       13.42  1.58    Male    Yes   Fri  Lunch     2              6.71
# 225       16.27  2.50  Female    Yes   Fri  Lunch     2              8.14
# 226       10.09  2.00  Female    Yes   Fri  Lunch     2              5.04
#
#             Payer Name         CC Number Payment ID
# 77          John Davis    30344778738589   Thur4924
# 78          Chris Hahn  3591887177014031   Thur2863
# 79          Brian Diaz  4759290988169738   Thur9501
# 80        Louis Torres    38848369968464   Thur6453
# 81      William Martin  4550549048402707   Thur8232
# ..                 ...               ...        ...
# 222     Jason Lawrence  3505302934650403    Fri6624
# 223        Mary Rivera  5343428579353069    Fri6014
# 224  Ronald Vaughn DVM   341503466406403    Fri5959
# 225     Whitney Arnold  3579111947217428    Fri6665
# 226         Ruth Weiss  5268689490381635    Fri6359
#
# [68 rows x 11 columns]

# %%
df[(df['time']  == 'Lunch') & (df['sex'] == 'Female')]
# Out:
#      total_bill   tip     sex smoker   day   time  size  price_per_person  \
# 82        10.07  1.83  Female     No  Thur  Lunch     1             10.07
# 85        34.83  5.17  Female     No  Thur  Lunch     4              8.71
# 117       10.65  1.50  Female     No  Thur  Lunch     2              5.32
# 118       12.43  1.80  Female     No  Thur  Lunch     2              6.22
# 119       24.08  2.92  Female     No  Thur  Lunch     4              6.02
# 121       13.42  1.68  Female     No  Thur  Lunch     2              6.71
# 124       12.48  2.52  Female     No  Thur  Lunch     2              6.24
# 125       29.80  4.20  Female     No  Thur  Lunch     6              4.97
# 127       14.52  2.00  Female     No  Thur  Lunch     2              7.26
# 128       11.38  2.00  Female     No  Thur  Lunch     2              5.69
# 131       20.27  2.83  Female     No  Thur  Lunch     2             10.14
# 132       11.17  1.50  Female     No  Thur  Lunch     2              5.58
# 133       12.26  2.00  Female     No  Thur  Lunch     2              6.13
# 134       18.26  3.25  Female     No  Thur  Lunch     2              9.13
# 135        8.51  1.25  Female     No  Thur  Lunch     2              4.26
# 136       10.33  2.00  Female     No  Thur  Lunch     2              5.16
# 137       14.15  2.00  Female     No  Thur  Lunch     2              7.08
# 139       13.16  2.75  Female     No  Thur  Lunch     2              6.58
# 140       17.47  3.50  Female     No  Thur  Lunch     2              8.74
# 143       27.05  5.00  Female     No  Thur  Lunch     6              4.51
# 144       16.43  2.30  Female     No  Thur  Lunch     2              8.22
# 145        8.35  1.50  Female     No  Thur  Lunch     2              4.18
# 146       18.64  1.36  Female     No  Thur  Lunch     3              6.21
# 147       11.87  1.63  Female     No  Thur  Lunch     2              5.94
# 191       19.81  4.19  Female    Yes  Thur  Lunch     2              9.90
# 197       43.11  5.00  Female    Yes  Thur  Lunch     4             10.78
# 198       13.00  2.00  Female    Yes  Thur  Lunch     2              6.50
# 201       12.74  2.01  Female    Yes  Thur  Lunch     2              6.37
# 202       13.00  2.00  Female    Yes  Thur  Lunch     2              6.50
# 203       16.40  2.50  Female    Yes  Thur  Lunch     2              8.20
# 205       16.47  3.23  Female    Yes  Thur  Lunch     3              5.49
# 221       13.42  3.48  Female    Yes   Fri  Lunch     2              6.71
# 223       15.98  3.00  Female     No   Fri  Lunch     3              5.33
# 225       16.27  2.50  Female    Yes   Fri  Lunch     2              8.14
# 226       10.09  2.00  Female    Yes   Fri  Lunch     2              5.04
#
#               Payer Name         CC Number Payment ID
# 82           Julie Moody      630413282843   Thur4909
# 85           Shawna Cook  6011787464177340   Thur7972
# 117          Linda Zhang  3560509622598239   Thur9593
# 118  Dr. Caroline Tucker      502047186908   Thur8084
# 119       Melanie Jordan      676212062720   Thur8063
# 121         Laura Garcia  5181484390945653   Thur2158
# 124          Jordan Diaz  4472778228206399    Thur208
# 125       Angela Sanchez      503857080488   Thur3948
# 127      Jessica Simmons   213102478792200   Thur1512
# 128    Christine Perkins  3548391118913991   Thur8551
# 131         Ashley Burke  5394652998970066   Thur9005
# 132      Taylor Gonzalez  6011990685390011   Thur7783
# 133         Kaitlin Wolf      676348318145   Thur1561
# 134      Karen Rodriguez     4952604748911     Thur75
# 135       Rebecca Harris  4320272020376174   Thur6600
# 136          Donna Kelly   180048553626376   Thur1393
# 137       Vanessa Morris   213189344156819   Thur3890
# 139        Lindsey Meyer      676239597203   Thur6245
# 140           Kayla Rios  5233918213804470   Thur3906
# 143         Regina Jones     4311048695487   Thur6179
# 144          Linda Jones  6542729219645658   Thur9002
# 145            Amy Young     4285454264477   Thur9331
# 146        Kelly Estrada       60463302327   Thur3941
# 147   Annette Cunningham      675937746864   Thur4780
# 191          Kristy Boyd  4317015327600068    Thur967
# 197          Brooke Soto  5544902205760175   Thur9313
# 198       Katherine Bond     4926725945192    Thur437
# 201        Abigail Parks  3586645396220590   Thur2544
# 202          Ashley Shaw   180088043008041   Thur1301
# 203          Toni Brooks  3582289985920239   Thur7770
# 205          Carly Reyes     4787787236486   Thur8084
# 221       Leslie Kaufman   379437981958785    Fri7511
# 223          Mary Rivera  5343428579353069    Fri6014
# 225       Whitney Arnold  3579111947217428    Fri6665
# 226           Ruth Weiss  5268689490381635    Fri6359

# %%
cv = df[(df['time']  == 'Lunch') & (df['sex'] == 'Female')]

# %%
np.shape(cv)
# Out:
# (35, 11)

# %%
df[['tip']]
# Out:
#       tip
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# ..    ...
# 239  5.92
# 240  2.00
# 241  2.00
# 242  1.75
# 243  3.00
#
# [244 rows x 1 columns]

# %%
df[(df['day'] =='Sun') & (df['size']== 3)]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 16        10.33  1.67  Female     No  Sun  Dinner     3              3.44
# 17        16.29  3.71    Male     No  Sun  Dinner     3              5.43
# 18        16.97  3.50  Female     No  Sun  Dinner     3              5.66
# 48        28.55  2.05    Male     No  Sun  Dinner     3              9.52
# 112       38.07  4.00    Male     No  Sun  Dinner     3             12.69
# 114       25.71  4.00  Female     No  Sun  Dinner     3              8.57
# 152       17.26  2.74    Male     No  Sun  Dinner     3              5.75
# 162       16.21  2.00  Female     No  Sun  Dinner     3              5.40
# 165       24.52  3.48    Male     No  Sun  Dinner     3              8.17
# 182       45.35  3.50    Male    Yes  Sun  Dinner     3             15.12
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3              6.97
# 188       18.15  3.50  Female    Yes  Sun  Dinner     3              6.05
# 189       23.10  4.00    Male    Yes  Sun  Dinner     3              7.70
#
#            Payer Name         CC Number Payment ID
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 16   Elizabeth Foster  4240025044626033    Sun9715
# 17       John Pittman  6521340257218708    Sun2998
# 18     Laura Martinez    30422275171379    Sun2789
# 48      Austin Fisher  6011481668986587    Sun4142
# 112        Jeff Lopez  3572865915176463     Sun591
# 114       Katie Smith  5400160161311292    Sun6492
# 152     Gregory Smith     4292362333741    Sun5205
# 162    Jennifer Baird  4227834176859693    Sun5521
# 165      Jacob Hansen     4031116007387    Sun9043
# 182      Jose Parsons  4112207559459910    Sun2337
# 186    Heidi Atkinson  4422858423131187    Sun4254
# 188    Glenda Wiggins      578329325307     Sun430
# 189   Richard Stevens  3560193117506187    Sun1821

# %%
df[(df['day'] =='Sun') & (df['day']== 'Sat') | (df['smoker']== 'Yes')]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 56        38.01  3.00    Male    Yes  Sat  Dinner     4              9.50
# 58        11.24  1.76    Male    Yes  Sat  Dinner     2              5.62
# 60        20.29  3.21    Male    Yes  Sat  Dinner     2             10.14
# 61        13.81  2.00    Male    Yes  Sat  Dinner     2              6.90
# 62        11.02  1.98    Male    Yes  Sat  Dinner     2              5.51
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 234       15.53  3.00    Male    Yes  Sat  Dinner     2              7.76
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2              6.30
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2             16.42
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
#
#                 Payer Name         CC Number Payment ID
# 56   James Christensen DDS   349793629453226    Sat8903
# 58           Troy Guerrero  3560782621035582    Sat6683
# 60          Anthony Mclean   347614304015027    Sat2353
# 61          Ryan Hernandez     4766834726806    Sat3030
# 62             Joseph Hart   180046232326178    Sat2265
# ..                     ...               ...        ...
# 234          Tracy Douglas  4097938155941930    Sat7220
# 236          Matthew Myers  3543676378973965    Sat5032
# 237           Thomas Brown  4284722681265508    Sat2929
# 240         Monica Sanders  3506806155565404    Sat1766
# 241             Keith Wong  6011891618747196    Sat3880
#
# [93 rows x 11 columns]

# %% [markdown]
# # Useful Methods
#
# Let's cover some useful methods and functions built in to pandas. This is actually just a small sampling of the functions and methods available in Pandas, but they are some of the most commonly used.
# The [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/index.html) is a great resource to continue exploring more methods and functions (we will introduce more further along in the course).
# Here is a list of functions and methods we'll cover here (click on one to jump to that section in this notebook.):
#
# * [apply() method](#apply_method)
# * [apply() with a function](#apply_function)
# * [apply() with a lambda expression](#apply_lambda)
# * [apply() on multiple columns](#apply_multiple)
# * [describe()](#describe)
# * [sort_values()](#sort)
# * [corr()](#corr)
# * [idxmin and idxmax](#idx)
# * [value_counts](#v_c)
# * [replace](#replace)
# * [unique and nunique](#uni)
# * [map](#map)
# * [duplicated and drop_duplicates](#dup)
# * [between](#bet)
# * [sample](#sample)
# * [nlargest](#n)
#
# Make sure to view the video lessons to get the full explanation!

# %% [markdown]
# <a id='apply_method'></a>
#
# ## The .apply() method
#
# Here we will learn about a very useful method known as **apply** on a DataFrame. This allows us to apply and broadcast custom functions on a DataFrame column

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# <a id='apply_function'></a>
# ### apply with a function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
def Last_digits(CC_No):
    return str(CC_No)[-4:]

# %%
df['CC Number'].apply(Last_digits)
# Out:
# 0      3410
# 1      9230
# 2      1322
# 3      5994
# 4      7221
#        ...
# 239    2842
# 240    5404
# 241    7196
# 242    0950
# 243    8139
# Name: CC Number, Length: 244, dtype: object

# %%
# Createing new column 'Last_four'
df['Last_four'] = df['CC Number'].apply(Last_digits)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID Last_four
# 0    Christy Cunningham  3560325168603410    Sun2959      3410
# 1        Douglas Tucker  4478071379779230    Sun4608      9230
# 2        Travis Walters  6011812112971322    Sun4458      1322
# 3      Nathaniel Harris  4676137647685994    Sun5260      5994
# 4          Tonya Carter  4832732618637221    Sun2251      7221
# ..                  ...               ...        ...       ...
# 239       Michael Avila  5296068606052842    Sat2657      2842
# 240      Monica Sanders  3506806155565404    Sat1766      5404
# 241          Keith Wong  6011891618747196    Sat3880      7196
# 242        Dennis Dixon     4375220550950      Sat17      0950
# 243     Michelle Hardin  3511451626698139    Thur672      8139
#
# [244 rows x 12 columns]

# %% [markdown]
# ### Using .apply() with more complex functions

# %%
df['tip'].mean()
# Out:
# 2.9982786885245902

# %%
def rate(tp):
    if tp < 2:
        return ' 2 * * '
    elif tp >= 2 and tp < 4:
        return '3 * * *'
    else:
        return '5 * * * * * '
    
rate(5)
# Out:
# '5 * * * * * '

# %%
df['Rating'] = df['tip'].apply(rate)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID Last_four        Rating
# 0    Christy Cunningham  3560325168603410    Sun2959      3410        2 * *
# 1        Douglas Tucker  4478071379779230    Sun4608      9230        2 * *
# 2        Travis Walters  6011812112971322    Sun4458      1322       3 * * *
# 3      Nathaniel Harris  4676137647685994    Sun5260      5994       3 * * *
# 4          Tonya Carter  4832732618637221    Sun2251      7221       3 * * *
# ..                  ...               ...        ...       ...           ...
# 239       Michael Avila  5296068606052842    Sat2657      2842  5 * * * * *
# 240      Monica Sanders  3506806155565404    Sat1766      5404       3 * * *
# 241          Keith Wong  6011891618747196    Sat3880      7196       3 * * *
# 242        Dennis Dixon     4375220550950      Sat17      0950        2 * *
# 243     Michelle Hardin  3511451626698139    Thur672      8139       3 * * *
#
# [244 rows x 13 columns]

# %% [markdown]
# <a id='apply_lambda'></a>
# ### apply with lambda

# %%
def sample (pins):
    return pins * 2

# %%
lambda pins : pins *2
# Out:
# <function __main__.<lambda>(pins)>

# %%
sample(2.345)
# Out:
# 4.69

# %%
df['sample']=df['total_bill'].apply(lambda bill:bill*0.18)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID Last_four        Rating  \
# 0    Christy Cunningham  3560325168603410    Sun2959      3410        2 * *
# 1        Douglas Tucker  4478071379779230    Sun4608      9230        2 * *
# 2        Travis Walters  6011812112971322    Sun4458      1322       3 * * *
# 3      Nathaniel Harris  4676137647685994    Sun5260      5994       3 * * *
# 4          Tonya Carter  4832732618637221    Sun2251      7221       3 * * *
# ..                  ...               ...        ...       ...           ...
# 239       Michael Avila  5296068606052842    Sat2657      2842  5 * * * * *
# 240      Monica Sanders  3506806155565404    Sat1766      5404       3 * * *
# 241          Keith Wong  6011891618747196    Sat3880      7196       3 * * *
# 242        Dennis Dixon     4375220550950      Sat17      0950        2 * *
# 243     Michelle Hardin  3511451626698139    Thur672      8139       3 * * *
#
#      sample
# 0    3.0582
# 1    1.8612
# 2    3.7818
# 3    4.2624
# 4    4.4262
# ..      ...
# 239  5.2254
# 240  4.8924
# 241  4.0806
# 242  3.2076
# 243  3.3804
#
# [244 rows x 14 columns]

# %% [markdown]
# <a id='apply_multiple'></a>
# ## apply that uses multiple columns
#
# Note, there are several ways to do this:
#
# https://stackoverflow.com/questions/19914937/applying-function-with-multiple-arguments-to-create-a-new-pandas-column

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Last_four   Rating  sample
# 0  Christy Cunningham  3560325168603410    Sun2959      3410   2 * *   3.0582
# 1      Douglas Tucker  4478071379779230    Sun4608      9230   2 * *   1.8612
# 2      Travis Walters  6011812112971322    Sun4458      1322  3 * * *  3.7818
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994  3 * * *  4.2624
# 4        Tonya Carter  4832732618637221    Sun2251      7221  3 * * *  4.4262

# %%
def Quality(total_bill,tip):
    if tip/total_bill > 0.25:
        return 'Generous'
    else:
        return 'Other'

# %%
df['Tip Quality']=df[['total_bill','tip']].apply(lambda df:Quality(df['total_bill'],df['tip']),axis=1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID Last_four        Rating  \
# 0    Christy Cunningham  3560325168603410    Sun2959      3410        2 * *
# 1        Douglas Tucker  4478071379779230    Sun4608      9230        2 * *
# 2        Travis Walters  6011812112971322    Sun4458      1322       3 * * *
# 3      Nathaniel Harris  4676137647685994    Sun5260      5994       3 * * *
# 4          Tonya Carter  4832732618637221    Sun2251      7221       3 * * *
# ..                  ...               ...        ...       ...           ...
# 239       Michael Avila  5296068606052842    Sat2657      2842  5 * * * * *
# 240      Monica Sanders  3506806155565404    Sat1766      5404       3 * * *
# 241          Keith Wong  6011891618747196    Sat3880      7196       3 * * *
# 242        Dennis Dixon     4375220550950      Sat17      0950        2 * *
# 243     Michelle Hardin  3511451626698139    Thur672      8139       3 * * *
#
#      sample Tip Quality
# 0    3.0582       Other
# 1    1.8612       Other
# 2    3.7818       Other
# 3    4.2624       Other
# 4    4.4262       Other
# ..      ...         ...
# 239  5.2254       Other
# 240  4.8924       Other
# 241  4.0806       Other
# 242  3.2076       Other
# 243  3.3804       Other
#
# [244 rows x 15 columns]

# %%
df['Tip Quality'] = np.vectorize(Quality)(df['total_bill'],df['tip'])

# %%
df['Tip Quality']
# Out:
# 0      Other
# 1      Other
# 2      Other
# 3      Other
# 4      Other
#        ...
# 239    Other
# 240    Other
# 241    Other
# 242    Other
# 243    Other
# Name: Tip Quality, Length: 244, dtype: object

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID Last_four        Rating  \
# 239    Michael Avila  5296068606052842    Sat2657      2842  5 * * * * *
# 240   Monica Sanders  3506806155565404    Sat1766      5404       3 * * *
# 241       Keith Wong  6011891618747196    Sat3880      7196       3 * * *
# 242     Dennis Dixon     4375220550950      Sat17      0950        2 * *
# 243  Michelle Hardin  3511451626698139    Thur672      8139       3 * * *
#
#      sample Tip Quality
# 239  5.2254       Other
# 240  4.8924       Other
# 241  4.0806       Other
# 242  3.2076       Other
# 243  3.3804       Other

# %%
import timeit 
  
# code snippet to be executed only once 
setup =  """
import numpy as np
import pandas as pd
df = pd.read_csv('C:\\Users\\DELL\\Udemy classes\\UNZIP_FOR_NOTEBOOKS_FINAL\\03-Pandas\\tips.csv')
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"        
""" 
  
# code snippet whose execution time is to be measured 
stmt_one = ''' 
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
'''

stmt_two = '''
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])
'''

# %%
timeit.timeit(setup=setup,stmt = stmt_one,number = 1000)
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\DELL\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\DELL\AppData\Local\Temp\ipykernel_12016\168079036.py", line 1, in <module>
#     timeit.timeit(setup=setup,stmt = stmt_one,number = 1000)
#
#   File "C:\Users\DELL\anaconda3\lib\timeit.py", line 233, in timeit
#     return Timer(stmt, setup, timer, globals).timeit(number)
#
#   File "C:\Users\DELL\anaconda3\lib\timeit.py", line 110, in __init__
#     compile(setup, dummy_src_name, "exec")
#
#   File "<timeit-src>", line 4
#     df = pd.read_csv('C:\Users\DELL\Udemy classes\UNZIP_FOR_NOTEBOOKS_FINAL\03-Pandas\tips.csv')
#                                                                                                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# Wow! Vectorization is much faster! Keep np.vectorize() in mind for the future.
#
# Full Details: https://docs.scipy.org/doc/numpy/reference/generated/numpy.vectorize.html

# %% [markdown]
# <a id='describe'></a>
# ### df.describe for statistical summaries

# %%
df.describe()

# %%
df.describe().transpose()

# %% [markdown]
# <a id='sort'></a>
# ### sort_values()

# %%
df.sort_values('size')

# %%
# Helpful if you want to reorder after a sort
# https://stackoverflow.com/questions/13148429/how-to-change-the-order-of-dataframe-columns
df.sort_values(['tip','size','day'])

# %% [markdown]
# <a id='corr'></a>
# ## df.corr() for correlation checks
#
# [Wikipedia on Correlation](https://en.wikipedia.org/wiki/Correlation_and_dependence)

# %%
df.corr()

# %%
df[['total_bill','tip','sample']].corr()

# %% [markdown]
# <a id='idx'></a>
# ### idxmin and idxmax

# %%
df.index

# %%
df['total_bill'].max()

# %%
df['total_bill'].idxmax()

# %%
df.iloc[170]

# %%
df['total_bill'].min()

# %%
df['total_bill'].idxmin()

# %%
df.iloc[67]

# %% [markdown]
# <a id='v_c'></a>
# ### value_counts
#
# Nice method to quickly get a count per category. Only makes sense on categorical columns.

# %%
df.head()

# %%
df['day'].value_counts()

# %%
df['time'].value_counts()

# %%
df['size'].value_counts()

# %%
df['sex'].value_counts()

# %% [markdown]
# <a id='replace'></a>
#
# ### replace
#
# Quickly replace values with another one.

# %%
df.head()

# %%
df['Tip Quality'].replace(to_replace='Other',value='Ok')

# %%
df

# %%
df['Tip Quality'] = df['Tip Quality'].replace(to_replace='Other',value='Ok')

# %%
df

# %% [markdown]
# <a id='uni'></a>
# ### unique

# %%
df['size'].unique()

# %%
df['size'].nunique()

# %%
df['sex'].unique()

# %%
df['sex'].nunique()

# %%
df['Rating'].unique()

# %%
df['Rating'].nunique()

# %% [markdown]
# <a id='map'></a>
# ### map

# %%
my_map = {'Dinner':'D','Lunch':'L'}

# %%
df['time']=df['time'].map(my_map)

# %%
df

# %% [markdown]
# <a id='dup'></a>
# ## Duplicates
#
# ### .duplicated() and .drop_duplicates()

# %%
# Returns True for the 1st instance of a duplicated row
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
simple_df = pd.DataFrame([1,2,2],['a','b','c'])

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# dtype: bool

# %%
simple_df.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %%
df.drop_duplicates()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID Last_four        Rating  \
# 0    Christy Cunningham  3560325168603410    Sun2959      3410        2 * *
# 1        Douglas Tucker  4478071379779230    Sun4608      9230        2 * *
# 2        Travis Walters  6011812112971322    Sun4458      1322       3 * * *
# 3      Nathaniel Harris  4676137647685994    Sun5260      5994       3 * * *
# 4          Tonya Carter  4832732618637221    Sun2251      7221       3 * * *
# ..                  ...               ...        ...       ...           ...
# 239       Michael Avila  5296068606052842    Sat2657      2842  5 * * * * *
# 240      Monica Sanders  3506806155565404    Sat1766      5404       3 * * *
# 241          Keith Wong  6011891618747196    Sat3880      7196       3 * * *
# 242        Dennis Dixon     4375220550950      Sat17      0950        2 * *
# 243     Michelle Hardin  3511451626698139    Thur672      8139       3 * * *
#
#      sample Tip Quality
# 0    3.0582       Other
# 1    1.8612       Other
# 2    3.7818       Other
# 3    4.2624       Other
# 4    4.4262       Other
# ..      ...         ...
# 239  5.2254       Other
# 240  4.8924       Other
# 241  4.0806       Other
# 242  3.2076       Other
# 243  3.3804       Other
#
# [244 rows x 15 columns]

# %% [markdown]
# <a id='bet'></a>
# ## between
#
# left: A scalar value that defines the left boundary
# right: A scalar value that defines the right boundary
# inclusive: A Boolean value which is True by default. If False, it excludes the two passed arguments while checking.

# %%
df['total_bill'].between(10,50,inclusive = True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12016\940853958.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df['total_bill'].between(10,50,inclusive = True)
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 239    True
# 240    True
# 241    True
# 242    True
# 243    True
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df['total_bill'].between(15,20,inclusive = True)]
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12016\275866618.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df[df['total_bill'].between(15,20,inclusive = True)]
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 12        15.42  1.57    Male     No   Sun  Dinner     2              7.71
# 13        18.43  3.00    Male     No   Sun  Dinner     4              4.61
# 17        16.29  3.71    Male     No   Sun  Dinner     3              5.43
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2              8.14
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3              5.23
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID Last_four   Rating  \
# 0    Christy Cunningham  3560325168603410    Sun2959      3410   2 * *
# 8       Joseph Mcdonald  3522866365840377    Sun6820      0377   2 * *
# 12      Chad Harrington      577040572932    Sun1300      2932   2 * *
# 13         Joshua Jones  6011163105616890    Sun2971      6890  3 * * *
# 17         John Pittman  6521340257218708    Sun2998      8708  3 * * *
# ..                  ...               ...        ...       ...      ...
# 225      Whitney Arnold  3579111947217428    Fri6665      7428  3 * * *
# 231         Jason Parks     4812333796161    Sat6334      6161  3 * * *
# 234       Tracy Douglas  4097938155941930    Sat7220      1930  3 * * *
# 242        Dennis Dixon     4375220550950      Sat17      0950   2 * *
# 243     Michelle Hardin  3511451626698139    Thur672      8139  3 * * *
#
#      sample Tip Quality
# 0    3.0582       Other
# 8    2.7072       Other
# 12   2.7756       Other
# 13   3.3174       Other
# 17   2.9322       Other
# ..      ...         ...
# 225  2.9286       Other
# 231  2.8242       Other
# 234  2.7954       Other
# 242  3.2076       Other
# 243  3.3804       Other
#
# [67 rows x 15 columns]

# %% [markdown]
# <a id='sample'></a>
# ## sample

# %%
df.sample(23)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 104       20.92  4.08  Female     No   Sat  Dinner     2             10.46
# 70        12.02  1.97    Male     No   Sat  Dinner     2              6.01
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2              6.50
# 177       14.48  2.00    Male    Yes   Sun  Dinner     2              7.24
# 147       11.87  1.63  Female     No  Thur   Lunch     2              5.94
# 152       17.26  2.74    Male     No   Sun  Dinner     3              5.75
# 84        15.98  2.03    Male     No  Thur   Lunch     2              7.99
# 195        7.56  1.44    Male     No  Thur   Lunch     2              3.78
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 132       11.17  1.50  Female     No  Thur   Lunch     2              5.58
# 46        22.23  5.00    Male     No   Sun  Dinner     2             11.12
# 124       12.48  2.52  Female     No  Thur   Lunch     2              6.24
# 185       20.69  5.00    Male     No   Sun  Dinner     5              4.14
# 173       31.85  3.18    Male    Yes   Sun  Dinner     2             15.92
# 160       21.50  3.50    Male     No   Sun  Dinner     4              5.38
# 232       11.61  3.39    Male     No   Sat  Dinner     2              5.80
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 35        24.06  3.60    Male     No   Sat  Dinner     3              8.02
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 181       23.33  5.65    Male    Yes   Sun  Dinner     2             11.66
# 167       31.71  4.50    Male     No   Sun  Dinner     4              7.93
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4              5.13
#
#               Payer Name         CC Number Payment ID Last_four        Rating  \
# 104  Gabrielle Frederick  4013010878990106    Sat3194      0106  5 * * * * *
# 70             Max Brown   213139760497718    Sat2100      7718        2 * *
# 198       Katherine Bond     4926725945192    Thur437      5192       3 * * *
# 177          John Dudley  4565183162071073    Sun6203      1073       3 * * *
# 147   Annette Cunningham      675937746864   Thur4780      6864        2 * *
# 152        Gregory Smith     4292362333741    Sun5205      3741       3 * * *
# 84           Jason Jones  4442984204923315   Thur1944      3315       3 * * *
# 195        Michael White  4865390263095532    Thur697      5532        2 * *
# 239        Michael Avila  5296068606052842    Sat2657      2842  5 * * * * *
# 132      Taylor Gonzalez  6011990685390011   Thur7783      0011        2 * *
# 46        Joshua Gilmore     4292072734899    Sun7097      4899  5 * * * * *
# 124          Jordan Diaz  4472778228206399    Thur208      6399       3 * * *
# 185        Joseph Howell    30362407455623    Sun5842      5623  5 * * * * *
# 173          Scott Perez  3577115550328507    Sun9335      8507       3 * * *
# 160      Travis Gonzalez  3527668419764685     Sun245      4685       3 * * *
# 232         James Taylor  6011482917327995    Sat2124      7995       3 * * *
# 242         Dennis Dixon     4375220550950      Sat17      0950        2 * *
# 35        Joseph Mullins  5519770449260299     Sat632      0299       3 * * *
# 238       Kimberly Crane      676184013727    Sat9777      3727  5 * * * * *
# 181            Jason Cox  6556931703586223    Sun3402      6223  5 * * * * *
# 167       Michael Lawson  3566285921227119    Sun3719      7119  5 * * * * *
# 234        Tracy Douglas  4097938155941930    Sat7220      1930       3 * * *
# 204            Scott Kim  3570611756827620   Thur2160      7620  5 * * * * *
#
#      sample Tip Quality
# 104  3.7656       Other
# 70   2.1636       Other
# 198  2.3400       Other
# 177  2.6064       Other
# 147  2.1366       Other
# 152  3.1068       Other
# 84   2.8764       Other
# 195  1.3608       Other
# 239  5.2254       Other
# 132  2.0106       Other
# 46   4.0014       Other
# 124  2.2464       Other
# 185  3.7242       Other
# 173  5.7330       Other
# 160  3.8700       Other
# 232  2.0898    Generous
# 242  3.2076       Other
# 35   4.3308       Other
# 238  6.4494       Other
# 181  4.1994       Other
# 167  5.7078       Other
# 234  2.7954       Other
# 204  3.6954       Other

# %%
df.sample(frac=0.05)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 96        27.28  4.00    Male    Yes   Fri  Dinner     2             13.64
# 125       29.80  4.20  Female     No  Thur   Lunch     6              4.97
# 123       15.95  2.00    Male     No  Thur   Lunch     2              7.98
# 176       17.89  2.00    Male    Yes   Sun  Dinner     2              8.94
# 169       10.63  2.00  Female    Yes   Sat  Dinner     2              5.32
# 26        13.37  2.00    Male     No   Sat  Dinner     2              6.68
# 136       10.33  2.00  Female     No  Thur   Lunch     2              5.16
# 213       13.27  2.50  Female    Yes   Sat  Dinner     2              6.64
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2             12.64
# 145        8.35  1.50  Female     No  Thur   Lunch     2              4.18
# 60        20.29  3.21    Male    Yes   Sat  Dinner     2             10.14
#
#            Payer Name         CC Number Payment ID Last_four        Rating  \
# 96        Eric Carter  4563054452787961    Fri3159      7961  5 * * * * *
# 125    Angela Sanchez      503857080488   Thur3948      0488  5 * * * * *
# 123  Christopher Lang  4820629318698319   Thur1992      8319       3 * * *
# 176    Walter Simmons  6011481578696110    Sun5961      6110       3 * * *
# 169          Amy Hill  3536332481454019    Sat1788      4019       3 * * *
# 26         Kyle Avery  6531339539615499    Sat6651      5499       3 * * *
# 136       Donna Kelly   180048553626376   Thur1393      6376       3 * * *
# 213    Robin Andersen      580140531089    Sat1374      1089       3 * * *
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994       3 * * *
# 73       Julie Holmes  5418689346409571    Sat6065      9571  5 * * * * *
# 145         Amy Young     4285454264477   Thur9331      4477        2 * *
# 60     Anthony Mclean   347614304015027    Sat2353      5027       3 * * *
#
#      sample Tip Quality
# 96   4.9104       Other
# 125  5.3640       Other
# 123  2.8710       Other
# 176  3.2202       Other
# 169  1.9134       Other
# 26   2.4066       Other
# 136  1.8594       Other
# 213  2.3886       Other
# 3    4.2624       Other
# 73   4.5504       Other
# 145  1.5030       Other
# 60   3.6522       Other

# %% [markdown]
# <a id='n'></a>
# ## nlargest and nsmallest

# %%
df.nlargest(10,'total_bill')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 142       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
#
#           Payer Name         CC Number Payment ID Last_four        Rating  \
# 170    Gregory Clark  5473850968388236    Sat1954      8236  5 * * * * *
# 212  Alex Williamson      676218815212    Sat4590      5212  5 * * * * *
# 59       Brian Ortiz  6596453823950595    Sat8139      0595  5 * * * * *
# 156    Ryan Gonzales  3523151482063321    Sun7518      3321  5 * * * * *
# 182     Jose Parsons  4112207559459910    Sun2337      9910       3 * * *
# 102    Heather Cohen   379771118886604    Sat6240      6604       3 * * *
# 197      Brooke Soto  5544902205760175   Thur9313      0175  5 * * * * *
# 142     Eric Andrews  4356531761046453   Thur3621      6453  5 * * * * *
# 184      Stephen Cox  3547798222044029    Sun5140      4029       3 * * *
# 95     Aaron Bentley   180026611638690    Fri9628      8690  5 * * * * *
#
#      sample Tip Quality
# 170  9.1458       Other
# 212  8.6994       Other
# 59   8.6886       Other
# 156  8.6706       Other
# 182  8.1630       Other
# 102  7.9740       Other
# 197  7.7598       Other
# 142  7.4142       Other
# 184  7.2990       Other
# 95   7.2306       Other
